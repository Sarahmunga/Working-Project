# %% [markdown]
# ## Data Understanding

# %% [raw]
# This project uses the King County House Sales dataset because Emerald City Realtors and its prospective homesellers are all based in King County. The dataset includes all data of single-family home sales from 2014-2015. The dataset itself can be found in kc_house_data.csv in the data folder of this GitHub repository along with the descriptions of the features, found in column_names.md Further information about the features can be found on the King County Assessor Website
#
# The original dataset includes sales data for 21,597 homes with 20 different features, which include:
# date - Date house was sold
# price - Sale price (prediction target)
# bedrooms - Number of bedrooms
# bathrooms - Number of bathrooms
# sqft_living - Square footage of living space in the home
# sqft_lot - Square footage of the lot
# floors - Number of floors (levels) in house
# waterfront - Whether the house is on a waterfront
# view - Quality of view from house
# condition - How good the overall condition of the house is. Related to maintenance of house
# grade - Overall grade of the house. Related to the construction and design of the house
# sqft_above - Square footage of house apart from basement
# sqft_basement - Square footage of the basement
# yr_built - Year when house was built
# yr_renovated - Year when house was renovated
# zipcode - ZIP Code used by the United States Postal Service

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# #### Cleaning and Processing of Data

# %%
# Impport liriaries
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline
import warnings
import statsmodels.api as sm
import statsmodels.stats.api as sms
import statsmodels.formula.api as smf
import scipy.stats as stats
from statsmodels.stats.outliers_influence import variance_inflation_factor
warnings.filterwarnings('ignore')

# %%
# import data
df = pd.read_csv("/home/sarah/Phase2 project/KC-k/kc_house_data.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-56-8a976c9ede63> in <module>
#       1 # import data
# ----> 2 df = pd.read_csv("/home/sarah/Phase2 project/KC-k/kc_house_data.csv")
#
# ~/yes/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
# ...

# %%
#view the first five entries
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-b87727c772c5> in <module>
#       1 #view the first five entries
# ----> 2 df.head()
#
# NameError: name 'df' is not defined

# %%
# view information on the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     19221 non-null  float64
#  9   view           21534 non-null  float64
#  10  condition      21597 non-null  int64
#  11  grade          21597 non-null  int64
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  object
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   17755 non-null  float64
#  16  zipcode        21597 non-null  int64
# ...

# %% [raw]
# There are 21597 entiries and 21 columns. There are missing values in the data set in the Waterfront with 2376 missing values. The Yr_renovated as well has 3842 values.

# %%
# Checking for missing values
df.isna().sum()
# Out:
# id                  0
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2376
# view               63
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated     3842
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# dtype: int64

# %% [raw]
# Since there are 21,000 entries, the missing vaues can be replaced instead of being removed since it might affect the outcome if deleted.

# %%
# View for Statistics
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.159700e+04  2.159700e+04  21597.000000  21597.000000  21597.000000
# mean   4.580474e+09  5.402966e+05      3.373200      2.115826   2080.321850
# std    2.876736e+09  3.673681e+05      0.926299      0.768984    918.106125
# min    1.000102e+06  7.800000e+04      1.000000      0.500000    370.000000
# 25%    2.123049e+09  3.220000e+05      3.000000      1.750000   1430.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.159700e+04  21597.000000  19221.000000  21534.000000  21597.000000
# mean   1.509941e+04      1.494096      0.007596      0.233863      3.409825
# ...

# %% [raw]
# There seem to be outlier on the bedroom column with 33 bedrooms which doesnot seem to be okay. As well there are 8 bedrooms which I will categorize it as an outlier as well.

# %% [markdown]
# #### Waterfront Column

# %%
#check the summary statistcs of waterfront
df["waterfront"].describe()
# Out:
# count    19221.000000
# mean         0.007596
# std          0.086825
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: waterfront, dtype: float64

# %%
#calculate the median 
waterfront_median = df["waterfront"].median()
waterfront_median
# Out:
# 0.0

# %% [raw]
# we use the median to fill the missing values in the waterfront column

# %%
#fill the null values in the waterfrontcolumn with the median
df["waterfront"].fillna(waterfront_median, inplace = True)

# %%
# check if the replaced values have been actualized
df.isna().sum()
# Out:
# id                0
# date              0
# price             0
# bedrooms          0
# bathrooms         0
# sqft_living       0
# sqft_lot          0
# floors            0
# waterfront        0
# view             61
# condition         0
# grade             0
# sqft_above        0
# sqft_basement     0
# yr_built          0
# yr_renovated      0
# zipcode           0
# lat               0
# long              0
# sqft_living15     0
# sqft_lot15        0
# dtype: int64

# %%
#check the value count of each element in the column
df["waterfront"].value_counts()
# Out:
# 0.0    21001
# 1.0      142
# Name: waterfront, dtype: int64

# %% [raw]
# The data seems to be okay now, no missing values.

# %% [markdown]
# ### Price column

# %%
#Check the highest price for the house
df.sort_values("price")
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 15279    40000362    5/6/2014    78000.0         2       1.00          780
# 465    8658300340   5/23/2014    80000.0         1       0.75          430
# 16184  3028200080   3/24/2015    81000.0         2       1.00          730
# 8267   3883800011   11/5/2014    82000.0         3       1.00          860
# 2139   1623049041    5/8/2014    82500.0         2       1.00          520
# ...           ...         ...        ...       ...        ...          ...
# 1446   8907500070   4/13/2015  5350000.0         5       5.00         8000
# 4407   2470100110    8/4/2014  5570000.0         5       5.75         9200
# 9245   9208900037   9/19/2014  6890000.0         6       7.75         9890
# 3910   9808700762   6/11/2014  7060000.0         5       4.50        10040
# 7245   6762700020  10/13/2014  7700000.0         6       8.00        12050
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
#sort the dataframe according to price in descending order
df.sort_values("price", ascending=False).head()
# Out:
#               id        date      price  bedrooms  bathrooms  sqft_living  \
# 7245  6762700020  10/13/2014  7700000.0         6       8.00        12050
# 3910  9808700762   6/11/2014  7060000.0         5       4.50        10040
# 9245  9208900037   9/19/2014  6890000.0         6       7.75         9890
# 4407  2470100110    8/4/2014  5570000.0         5       5.75         9200
# 1446  8907500070   4/13/2015  5350000.0         5       5.00         8000
#
#       sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 7245     27600     2.5         0.0   3.0  ...     13        8570
# 3910     37325     2.0         1.0   2.0  ...     11        7680
# 9245     31374     2.0         0.0   4.0  ...     13        8860
# 4407     35069     2.0         0.0   0.0  ...     13        6200
# 1446     23985     2.0         0.0   4.0  ...     12        6720
#
#       sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %% [raw]
# The house that is highly priced has 6 bedrooms, 8 birthrooms and 27,600 square feet lot and is priced at 7700000.

# %% [markdown]
# ### Bedrooms Column

# %%
df.sort_values("bedrooms")
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 9877   1231000310   8/12/2014   713000.0         1       1.00         1180
# 9536   2658000115   6/18/2014   190000.0         1       1.00          720
# 14332  1523300180    7/9/2014   321500.0         1       1.00          730
# 14340  2009003136   8/22/2014   325000.0         1       1.00         1220
# 12823  1154100205  10/13/2014   305000.0         1       1.00          900
# ...           ...         ...        ...       ...        ...          ...
# 15147  5566100170  10/29/2014   650000.0        10       2.00         3610
# 13301   627300145   8/14/2014  1150000.0        10       5.25         4590
# 19239  8812401450  12/29/2014   660000.0        10       3.00         2920
# 8748   1773100755   8/21/2014   520000.0        11       3.00         3000
# 15856  2402100895   6/25/2014   640000.0        33       1.75         1620
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
df.sort_values("bedrooms", ascending=False)
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 15856  2402100895   6/25/2014   640000.0        33       1.75         1620
# 8748   1773100755   8/21/2014   520000.0        11       3.00         3000
# 13301   627300145   8/14/2014  1150000.0        10       5.25         4590
# 19239  8812401450  12/29/2014   660000.0        10       3.00         2920
# 15147  5566100170  10/29/2014   650000.0        10       2.00         3610
# ...           ...         ...        ...       ...        ...          ...
# 12472  1172000150   8/29/2014   238000.0         1       1.00          530
# 13316  4356200120  10/23/2014   248000.0         1       1.00          790
# 7010    203100460   9/24/2014   400000.0         1       1.00          530
# 3578   1925069006   12/3/2014   355000.0         1       0.75          530
# 14373  7518503065   6/23/2014   335000.0         1       1.00          720
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %% [raw]
# We seem to have outliers in the data with 33 bedrooms and 11 bedrooms. The house with 33 bedrooms seems to have 1 birthroom which doesnt make sense.

# %%
# Draw a plot of bedrooms and count.
plt.figure(figsize=(8,6))
sns.countplot(x = df['bedrooms'])

# %% [raw]
# From the figure above it shows that most houses has between 2 to 5 bedrooms. But we also have a house with 33 bedrooms but it looks like an outlier.

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data= df, x=df['price'], y=df['bedrooms'])

# %% [raw]
# We seem to still have the outlier so we delete them

# %%
# Drop the outliers in the data

df = df[(df.bedrooms != 33)]

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data= df, x=df['price'], y=df['bedrooms'])

# %% [raw]
# We have removed the outlier that was in the data

# %% [markdown]
# ### Sqft_Basement

# %%
df.sqft_basement.unique()
# Out:
# array(['0.0', '400.0', '910.0', '1530.0', '?', '730.0', '1700.0', '300.0',
#        '970.0', '760.0', '720.0', '700.0', '820.0', '780.0', '790.0',
#        '330.0', '1620.0', '360.0', '588.0', '1510.0', '410.0', '990.0',
#        '600.0', '560.0', '550.0', '1000.0', '1600.0', '500.0', '1040.0',
#        '880.0', '1010.0', '240.0', '265.0', '290.0', '800.0', '540.0',
#        '710.0', '840.0', '380.0', '770.0', '480.0', '570.0', '1490.0',
#        '620.0', '1250.0', '1270.0', '120.0', '650.0', '180.0', '1130.0',
#        '450.0', '1640.0', '1460.0', '1020.0', '1030.0', '750.0', '640.0',
#        '1070.0', '490.0', '1310.0', '630.0', '2000.0', '390.0', '430.0',
#        '850.0', '210.0', '1430.0', '1950.0', '440.0', '220.0', '1160.0',
#        '860.0', '580.0', '2060.0', '1820.0', '1180.0', '200.0', '1150.0',
#        '1200.0', '680.0', '530.0', '1450.0', '1170.0', '1080.0', '960.0',
#        '280.0', '870.0', '1100.0', '460.0', '1400.0', '660.0', '1220.0',
# ...

# %% [raw]
# we seem to have non value in our data. We should therefore remove it.And convert the data type from string to float.

# %%
#Dropping "?"
df = df[df.sqft_basement != "?"]

# %%
#convert the data type from string to float
df["sqft_basement"]= df["sqft_basement"].astype("float")

# %%
df["zipcode"]=df["zipcode"].astype("float")

# %%
df.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront       float64
# view             float64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement    float64
# yr_built           int64
# yr_renovated     float64
# zipcode          float64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %% [markdown]
# ### YR- Renovated

# %%
# Summary statistics of the column
df["yr_renovated"].describe()
# Out:
# count    17389.000000
# mean        82.991949
# std        398.481819
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max       2015.000000
# Name: yr_renovated, dtype: float64

# %%
yr_renovated = df["yr_renovated"].median()
yr_renovated
# Out:
# 0.0

# %%
#Replace the NAN values with the value of median "0"
df["yr_renovated"].fillna("yr_renovated_median", inplace = True)

# %%
#Check the highest price for the house
df.isna().sum()
# Out:
# id                0
# date              0
# price             0
# bedrooms          0
# bathrooms         0
# sqft_living       0
# sqft_lot          0
# floors            0
# waterfront        0
# view             61
# condition         0
# grade             0
# sqft_above        0
# sqft_basement     0
# yr_built          0
# yr_renovated      0
# zipcode           0
# lat               0
# long              0
# sqft_living15     0
# sqft_lot15        0
# dtype: int64

# %% [markdown]
# ### View

# %%
#check the summary statistcs of waterfront
df["view"].describe()
# Out:
# count    21082.000000
# mean         0.233327
# std          0.765066
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          4.000000
# Name: view, dtype: float64

# %%
#calculate the median 
view_median = df["view"].median()
view_median
# Out:
# 0.0

# %%
#We fill the missing values with median 
df["view"].fillna(view_median, inplace = True)

# %%
df.isna().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [raw]
# We are now good with the cleaning of data

# %% [markdown]
# ### Data manupulation

# %%
# show the relationship between categorical features with the target 
corr_matrix = df.corr()[[ 'price']].sort_values('price')
corr_matrix
# Out:
#                   price
# zipcode       -0.053166
# id            -0.015796
# long           0.022101
# condition      0.035290
# yr_built       0.054459
# sqft_lot15     0.083192
# sqft_lot       0.087937
# floors         0.256355
# waterfront     0.265969
# lat            0.306507
# bedrooms       0.309204
# sqft_basement  0.325008
# view           0.394885
# bathrooms      0.525889
# sqft_living15  0.586415
# sqft_above     0.605143
# grade          0.667738
# sqft_living    0.702328
# price          1.000000

# %%
#Heat map to show correlation of numerical features with price
plt.figure(figsize=(8, 12))
sns.heatmap(corr_matrix, annot = True, vmin = -1, vmax = 1, cmap = 'viridis')
plt.title('Correlations Between Numerical Features and Price', fontdict={'fontsize':14})
plt.ylabel('Feature');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-05d212c7b0f3> in <module>
#       1 #Heat map to show correlation of numerical features with price
# ----> 2 plt.figure(figsize=(8, 12))
#       3 sns.heatmap(corr_matrix, annot = True, vmin = -1, vmax = 1, cmap = 'viridis')
#       4 plt.title('Correlations Between Numerical Features and Price', fontdict={'fontsize':14})
#       5 plt.ylabel('Feature');
#
# NameError: name 'plt' is not defined

# %%
# save heatmap as .png file
# dpi - sets the resolution of the saved image in dots/inches
# bbox_inches - when set to 'tight' - does not allow the labels to be croppedplt.figure(figsize=(16, 6))
heatmap = sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':18}, pad=12);
plt.savefig('heatmap.png', dpi=300, bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-6740fbfbb59c> in <module>
#       2 # dpi - sets the resolution of the saved image in dots/inches
#       3 # bbox_inches - when set to 'tight' - does not allow the labels to be croppedplt.figure(figsize=(16, 6))
# ----> 4 heatmap = sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')
#       5 heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':18}, pad=12);
#       6 plt.savefig('heatmap.png', dpi=300, bbox_inches='tight')
#
# NameError: name 'sns' is not defined

# %%
#Presentation
# Let's visualize our categorical variables to see relationship to mean sale price for exploratory purposes

fig, axes = plt.subplots(nrows = 2, ncols = 3, figsize = (16,10))

categoricals = ['waterfront', 'view_YES', 'condition', 'grade', 'reno_status']

for col, ax in zip(categoricals, axes.flatten()):
    (kcdf.groupby(col)              # group values together by column of interest
        .mean()['price']            # take the mean of the saleprice for each group
        .sort_values()              # sort the groups in ascending order
        .plot
        .bar(ax = ax))                # create a bar graph on the ax
    
    ax.set_title(col)               # Make the title the name of the column
    
fig.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3ebee776312f> in <module>
#       2 # Let's visualize our categorical variables to see relationship to mean sale price for exploratory purposes
#       3
# ----> 4 fig, axes = plt.subplots(nrows = 2, ncols = 3, figsize = (16,10))
#       5
#       6 categoricals = ['waterfront', 'view_YES', 'condition', 'grade', 'reno_status']
#
# NameError: name 'plt' is not defined
